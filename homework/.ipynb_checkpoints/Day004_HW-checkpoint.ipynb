# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"10983102587","type":"CommitCommentEvent","actor":{"id":57988806,"login":"hamza-elghandour","display_login":"hamza-elghandour","gravatar_id":"","url":"https://api.github.com/users/hamza-elghandour","avatar_url":"https://avatars.githubusercontent.com/u/57988806?"},"repo":{"id":225085907,"name":"hamza-elghandour/Monsiteweb","url":"https://api.github.com/repos/hamza-elghandour/Monsiteweb"},"payload":{"comment":{"url":"https://api.github.com/repos/hamza-elghandour/Monsiteweb/comments/36209665","html_url":"https://github.com/hamza-elghandour/Monsiteweb/commit/87d9eee701de8be373f1439fde6d77c3ac83eab0#commitcomment-36209665","id":36209665,"node_id":"MDEzOkNvbW1pdENvbW1lbnQzNjIwOTY2NQ==","user":{"login":"hamza-elghandour","id":57988806,"node_id":"MDQ6VXNlcjU3OTg4ODA2","avatar_url":"https://avatars3.githubusercontent.com/u/57988806?v=4","gravatar_id":"","url":"https://api.github.com/users/hamza-elghandour","html_url":"https://github.com/hamza-elghandour","followers_url":"https://api.github.com/users/hamza-elghandour/followers","following_url":"https://api.github.com/users/hamza-elghandour/following{/other_user}","gists_url":"https://api.github.com/users/hamza-elghandour/gists{/gist_id}","starred_url":"https://api.github.com/users/hamza-elghandour/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/hamza-elghandour/subscriptions","organizations_url":"https://api.github.com/users/hamza-elghandour/orgs","repos_url":"https://api.github.com/users/hamza-elghandour/repos","events_url":"https://api.github.com/users/hamza-elghandour/events{/privacy}","received_events_url":"https://api.github.com/users/hamza-elghandour/received_events","type":"User","site_admin":false},"position":null,"line":null,"path":null,"commit_id":"87d9eee701de8be373f1439fde6d77c3ac83eab0","created_at":"2019-12-01T12:45:14Z","updated_at":"2019-12-01T12:45:14Z","author_association":"OWNER","body":"voila"}},"public":true,"created_at":"2019-12-01T12:45:14Z"},{"id":"10983102584","type":"PushEvent","actor":{"id":23319413,"login":"pakeji","display_login":"pakeji","gravatar_id":"","url":"https://api.github.com/users/pakeji","avatar_url":"https://avatars.githubusercontent.com/u/23319413?"},"repo":{"id":186872004,"name":"pequet/public-logs","url":"https://api.github.com/repos/pequet/public-logs"},"payload":{"push_id":4340241667,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"99b7b85c125f34985f2bf78d6d6fe2e89dc47801","before":"3baabf8bcd4f2b5ad037ebe0a82a0c2e7f63bc48","commits":[{"sha":"99b7b85c125f34985f2bf78d6d6fe2e89dc47801","author":{"email":"pakeji.co@gmail.com","name":"Pakeji"},"message":"Commit (December 01 2019 12:45:13 UTC)","distinct":true,"url":"https://api.github.com/repos/pequet/public-logs/commits/99b7b85c125f34985f2bf78d6d6fe2e89dc47801"}]},"public":true,"created_at":"2019-12-01T12:45:14Z"},{"id":"10983102586","type":"CreateEvent","actor":{"id":53108186,"login":"codestar-github-bot-1","display_login":"codestar-github-bot-1","gravatar_id":"","url":"https://api.github.com/users/codestar-github-bot-1","avatar_url":"https://avatars.githubusercontent.com/u/53108186?"},"repo":{"id":225159891,"name":"codestar-github-bot-1/user-public-seeded-repo-eu-west-3","url":"https://api.github.com/repos/codestar-github-bot-1/user-public-seeded-repo-eu-west-3"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":"Seeded Repository created by CFN","pusher_type":"user"},"public":true,"created_at":"2019-12-01T12:45:14Z"},{"id":"10983102580","type":"PushEvent","actor":{"id":4695856,"login":"pchiwan","display_login":"pchiwan","gravatar_id":"","url":"https://api.github.com/users/pchiwan","avatar_url":"https://avatars.githubusercontent.com/u/4695856?"},"repo":{"id":116390236,"name":"pchiwan/galaxy-explorer","url":"https://api.github.com/repos/pchiwan/galaxy-explorer"},"payload":{"push_id":4340241670,"size":1,"distinct_size":1,"ref":"refs/heads/add-swagger","head":"28e37e7bd9fa9ed318c4693d6b6904e04de4e4a2","before":"fd6b ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '10983102587',
#   'type': 'CommitCommentEvent',
#   'actor': {'id': 57988806,
#    'login': 'hamza-elghandour',
#    'display_login': 'hamza-elghandour',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hamza-elghandour',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57988806?'},
#   'repo': {'id': 225085907,
#    'name': 'hamza-elghandour/Monsiteweb',
#    'url': 'https://api.github.com/repos/hamza-elghandour/Monsiteweb'},
#   'payload': {'comment': {'url': 'https://api.github.com/repos/hamza-elghandour/Monsiteweb/comments/36209665',
#     'html_url': 'https://github.com/hamza-elghandour/Monsiteweb/commit/87d9eee701de8be373f1439fde6d77c3ac83eab0#commitcomment-36209665',
#     'id': 36209665,
#     'node_id': 'MDEzOkNvbW1pdENvbW1lbnQzNjIwOTY2NQ==',
#     'user': {'login': 'hamza-elghandour',
#      'id': 57988806,
#      'node_id': 'MDQ6VXNlcjU3OTg4ODA2',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/57988806?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/hamza-elghandour',
#      'html_url': 'https://github.com/hamza-elghandour',
#      'followers_url': 'https://api.github.com/users/hamza-elghandour/followers',
#      'following_url': 'https://api.github.com/users/hamza-elghandour/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/hamza-elghandour/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/hamza-elghandour/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/hamza-elghandour/subscriptions',
#      'organizations_url': 'https://api.github.com/users/hamza-elghandour/orgs',
#      'repos_url': 'https://api.github.com/users/hamza-elghandour/repos',
#      'events_url': 'https://api.github.com/users/hamza-elghandour/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/hamza-elghandour/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'position': None,
#     'line': None,
#     'path': None,
#     'commit_id': '87d9eee701de8be373f1439fde6d77c3ac83eab0',
#     'created_at': '2019-12-01T12:45:14Z',
#     'updated_at': '2019-12-01T12:45:14Z',
#     'author_association': 'OWNER',
#     'body': 'voila'}},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102584',
#   'type': 'PushEvent',
#   'actor': {'id': 23319413,
#    'login': 'pakeji',
#    'display_login': 'pakeji',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pakeji',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23319413?'},
#   'repo': {'id': 186872004,
#    'name': 'pequet/public-logs',
#    'url': 'https://api.github.com/repos/pequet/public-logs'},
#   'payload': {'push_id': 4340241667,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '99b7b85c125f34985f2bf78d6d6fe2e89dc47801',
#    'before': '3baabf8bcd4f2b5ad037ebe0a82a0c2e7f63bc48',
#    'commits': [{'sha': '99b7b85c125f34985f2bf78d6d6fe2e89dc47801',
#      'author': {'email': 'pakeji.co@gmail.com', 'name': 'Pakeji'},
#      'message': 'Commit (December 01 2019 12:45:13 UTC)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pequet/public-logs/commits/99b7b85c125f34985f2bf78d6d6fe2e89dc47801'}]},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102586',
#   'type': 'CreateEvent',
#   'actor': {'id': 53108186,
#    'login': 'codestar-github-bot-1',
#    'display_login': 'codestar-github-bot-1',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codestar-github-bot-1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/53108186?'},
#   'repo': {'id': 225159891,
#    'name': 'codestar-github-bot-1/user-public-seeded-repo-eu-west-3',
#    'url': 'https://api.github.com/repos/codestar-github-bot-1/user-public-seeded-repo-eu-west-3'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Seeded Repository created by CFN',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102580',
#   'type': 'PushEvent',
#   'actor': {'id': 4695856,
#    'login': 'pchiwan',
#    'display_login': 'pchiwan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pchiwan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4695856?'},
#   'repo': {'id': 116390236,
#    'name': 'pchiwan/galaxy-explorer',
#    'url': 'https://api.github.com/repos/pchiwan/galaxy-explorer'},
#   'payload': {'push_id': 4340241670,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/add-swagger',
#    'head': '28e37e7bd9fa9ed318c4693d6b6904e04de4e4a2',
#    'before': 'fd6bcd5ee2e4aa33f4edf300784a0504abf68962',
#    'commits': [{'sha': '28e37e7bd9fa9ed318c4693d6b6904e04de4e4a2',
#      'author': {'email': 'pchiwan@gmail.com', 'name': 'Sílvia Mur'},
#      'message': 'Rename package.json scripts',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pchiwan/galaxy-explorer/commits/28e37e7bd9fa9ed318c4693d6b6904e04de4e4a2'}]},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102579',
#   'type': 'PushEvent',
#   'actor': {'id': 52121403,
#    'login': 'vSkyper',
#    'display_login': 'vSkyper',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/vSkyper',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52121403?'},
#   'repo': {'id': 225117794,
#    'name': 'vSkyper/Login',
#    'url': 'https://api.github.com/repos/vSkyper/Login'},
#   'payload': {'push_id': 4340241669,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '181091735f9453e8ef87866451efc905491a747f',
#    'before': '4dc79957b0adf3550e006602acf2ddbe005afaa2',
#    'commits': [{'sha': '181091735f9453e8ef87866451efc905491a747f',
#      'author': {'email': '52121403+vSkyper@users.noreply.github.com',
#       'name': 'vSkyper'},
#      'message': 'Update style.css',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/vSkyper/Login/commits/181091735f9453e8ef87866451efc905491a747f'}]},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102577',
#   'type': 'GollumEvent',
#   'actor': {'id': 5260612,
#    'login': 'iiison',
#    'display_login': 'iiison',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iiison',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5260612?'},
#   'repo': {'id': 150372636,
#    'name': 'iiison/react-form',
#    'url': 'https://api.github.com/repos/iiison/react-form'},
#   'payload': {'pages': [{'page_name': 'Select-Box',
#      'title': 'Select Box',
#      'summary': None,
#      'action': 'created',
#      'sha': 'd3304c92f257ee32b19d4363e23c80fc3febc115',
#      'html_url': 'https://github.com/iiison/react-form/wiki/Select-Box'}]},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102570',
#   'type': 'CreateEvent',
#   'actor': {'id': 33482573,
#    'login': 'joaonmatos',
#    'display_login': 'joaonmatos',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/joaonmatos',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33482573?'},
#   'repo': {'id': 225159321,
#    'name': 'joaonmatos/advent-of-code-2019',
#    'url': 'https://api.github.com/repos/joaonmatos/advent-of-code-2019'},
#   'payload': {'ref': 'add-license',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'My solutions to the Advent of Code 2019 problems',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102568',
#   'type': 'ForkEvent',
#   'actor': {'id': 46881834,
#    'login': 'redoubtei',
#    'display_login': 'redoubtei',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/redoubtei',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46881834?'},
#   'repo': {'id': 221657535,
#    'name': 'okaryu/WpfPopupSample',
#    'url': 'https://api.github.com/repos/okaryu/WpfPopupSample'},
#   'payload': {'forkee': {'id': 225159890,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjUxNTk4OTA=',
#     'name': 'WpfPopupSample',
#     'full_name': 'redoubtei/WpfPopupSample',
#     'private': False,
#     'owner': {'login': 'redoubtei',
#      'id': 46881834,
#      'node_id': 'MDQ6VXNlcjQ2ODgxODM0',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/46881834?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/redoubtei',
#      'html_url': 'https://github.com/redoubtei',
#      'followers_url': 'https://api.github.com/users/redoubtei/followers',
#      'following_url': 'https://api.github.com/users/redoubtei/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/redoubtei/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/redoubtei/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/redoubtei/subscriptions',
#      'organizations_url': 'https://api.github.com/users/redoubtei/orgs',
#      'repos_url': 'https://api.github.com/users/redoubtei/repos',
#      'events_url': 'https://api.github.com/users/redoubtei/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/redoubtei/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/redoubtei/WpfPopupSample',
#     'description': None,
#     'fork': True,
#     'url': 'https://api.github.com/repos/redoubtei/WpfPopupSample',
#     'forks_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/forks',
#     'keys_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/teams',
#     'hooks_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/hooks',
#     'issue_events_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/events',
#     'assignees_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/tags',
#     'blobs_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/languages',
#     'stargazers_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/stargazers',
#     'contributors_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/contributors',
#     'subscribers_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/subscribers',
#     'subscription_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/subscription',
#     'commits_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/merges',
#     'archive_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/downloads',
#     'issues_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/redoubtei/WpfPopupSample/deployments',
#     'created_at': '2019-12-01T12:45:13Z',
#     'updated_at': '2019-12-01T12:45:11Z',
#     'pushed_at': '2019-11-21T11:33:24Z',
#     'git_url': 'git://github.com/redoubtei/WpfPopupSample.git',
#     'ssh_url': 'git@github.com:redoubtei/WpfPopupSample.git',
#     'clone_url': 'https://github.com/redoubtei/WpfPopupSample.git',
#     'svn_url': 'https://github.com/redoubtei/WpfPopupSample',
#     'homepage': None,
#     'size': 12,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102563',
#   'type': 'CreateEvent',
#   'actor': {'id': 50525665,
#    'login': 'Mahnoor2809',
#    'display_login': 'Mahnoor2809',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Mahnoor2809',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50525665?'},
#   'repo': {'id': 223782365,
#    'name': 'Mahnoor2809/Python-Assignment-4',
#    'url': 'https://api.github.com/repos/Mahnoor2809/Python-Assignment-4'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102562',
#   'type': 'PushEvent',
#   'actor': {'id': 1398171,
#    'login': 'jgebal',
#    'display_login': 'jgebal',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jgebal',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1398171?'},
#   'repo': {'id': 225043449,
#    'name': 'jgebal/utPLSQL',
#    'url': 'https://api.github.com/repos/jgebal/utPLSQL'},
#   'payload': {'push_id': 4340241655,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop',
#    'head': 'b6a12c8ec850e554b6a8a4df75dbf126be427545',
#    'before': 'a7d62ee2bee30f7e7c6ca0b0dc65914d572a1a1f',
#    'commits': [{'sha': 'b6a12c8ec850e554b6a8a4df75dbf126be427545',
#      'author': {'email': 'jgebal@users.noreply.github.com',
#       'name': 'Jacek Gebal'},
#      'message': 'Testing',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/jgebal/utPLSQL/commits/b6a12c8ec850e554b6a8a4df75dbf126be427545'}]},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102560',
#   'type': 'PushEvent',
#   'actor': {'id': 20891252,
#    'login': 'adon0420023',
#    'display_login': 'adon0420023',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/adon0420023',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/20891252?'},
#   'repo': {'id': 225091066,
#    'name': 'adon0420023/Newton',
#    'url': 'https://api.github.com/repos/adon0420023/Newton'},
#   'payload': {'push_id': 4340241650,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1944a72a867d492a5d1af9b726b8f55eb85da07f',
#    'before': '0122774764c42c218e268f4e6333c8da60bc67c7',
#    'commits': [{'sha': '1944a72a867d492a5d1af9b726b8f55eb85da07f',
#      'author': {'email': 'adon042002@gmail.com', 'name': 'adon0420023'},
#      'message': 'GIT CloneShare Commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/adon0420023/Newton/commits/1944a72a867d492a5d1af9b726b8f55eb85da07f'}]},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102558',
#   'type': 'PushEvent',
#   'actor': {'id': 710357,
#    'login': 'knishioka',
#    'display_login': 'knishioka',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/knishioka',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/710357?'},
#   'repo': {'id': 224942607,
#    'name': 'knishioka/instagram-network',
#    'url': 'https://api.github.com/repos/knishioka/instagram-network'},
#   'payload': {'push_id': 4340241649,
#    'size': 2,
#    'distinct_size': 2,
#    'ref': 'refs/heads/master',
#    'head': '9179a6182ba7dd490df1c47f3df809c272304d27',
#    'before': 'aa779c985b270c13821e0d6b4243d3c945300198',
#    'commits': [{'sha': 'dd933c1cc000b4b7e127e4f467711cd2cddb0ede',
#      'author': {'email': 'nishioka@3idea.jp', 'name': 'Kenichiro Nishioka'},
#      'message': 'Modify lib path',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/knishioka/instagram-network/commits/dd933c1cc000b4b7e127e4f467711cd2cddb0ede'},
#     {'sha': '9179a6182ba7dd490df1c47f3df809c272304d27',
#      'author': {'email': 'nishioka@3idea.jp', 'name': 'Kenichiro Nishioka'},
#      'message': 'Add stats to get followee and follower count',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/knishioka/instagram-network/commits/9179a6182ba7dd490df1c47f3df809c272304d27'}]},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102556',
#   'type': 'PushEvent',
#   'actor': {'id': 15912889,
#    'login': 'isputra',
#    'display_login': 'isputra',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/isputra',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15912889?'},
#   'repo': {'id': 223730482,
#    'name': 'isputra/CppND-System-Monitor-Project',
#    'url': 'https://api.github.com/repos/isputra/CppND-System-Monitor-Project'},
#   'payload': {'push_id': 4340241647,
#    'size': 4,
#    'distinct_size': 4,
#    'ref': 'refs/heads/dev',
#    'head': '1ca061e42544653c5c8d9eb22637c0b1f88634f0',
#    'before': 'fbcf4cf896bd7f8fcc4576a5a32feaeb6591f1bb',
#    'commits': [{'sha': '826e2f0e874c1f8f8c78b1ced40ea8c63b540810',
#      'author': {'email': 'ikhsan_sz@yahoo.com', 'name': 'Ikhsan Putra'},
#      'message': 'calculate ram  as an int',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/isputra/CppND-System-Monitor-Project/commits/826e2f0e874c1f8f8c78b1ced40ea8c63b540810'},
#     {'sha': 'e8d03a73a46d2473da8daf5119fbae80a3399233',
#      'author': {'email': 'ikhsan_sz@yahoo.com', 'name': 'Ikhsan Putra'},
#      'message': 'Processor::Utilization is float',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/isputra/CppND-System-Monitor-Project/commits/e8d03a73a46d2473da8daf5119fbae80a3399233'},
#     {'sha': 'b0a6d34b91a96344fe9ae6878fc2a97b5312bb20',
#      'author': {'email': 'ikhsan_sz@yahoo.com', 'name': 'Ikhsan Putra'},
#      'message': 'min',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/isputra/CppND-System-Monitor-Project/commits/b0a6d34b91a96344fe9ae6878fc2a97b5312bb20'},
#     {'sha': '1ca061e42544653c5c8d9eb22637c0b1f88634f0',
#      'author': {'email': 'ikhsan_sz@yahoo.com', 'name': 'Ikhsan Putra'},
#      'message': 'define FREQ',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/isputra/CppND-System-Monitor-Project/commits/1ca061e42544653c5c8d9eb22637c0b1f88634f0'}]},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102557',
#   'type': 'IssuesEvent',
#   'actor': {'id': 56506250,
#    'login': 'Atrael',
#    'display_login': 'Atrael',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Atrael',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56506250?'},
#   'repo': {'id': 225155506,
#    'name': 'ichacz/Student_Skan',
#    'url': 'https://api.github.com/repos/ichacz/Student_Skan'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/ichacz/Student_Skan/issues/5',
#     'repository_url': 'https://api.github.com/repos/ichacz/Student_Skan',
#     'labels_url': 'https://api.github.com/repos/ichacz/Student_Skan/issues/5/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ichacz/Student_Skan/issues/5/comments',
#     'events_url': 'https://api.github.com/repos/ichacz/Student_Skan/issues/5/events',
#     'html_url': 'https://github.com/ichacz/Student_Skan/issues/5',
#     'id': 530725894,
#     'node_id': 'MDU6SXNzdWU1MzA3MjU4OTQ=',
#     'number': 5,
#     'title': 'Karol_Duś_USER_STORY_SPRAWDZANIE_ILOŚCI_OBECNOŚCI',
#     'user': {'login': 'Atrael',
#      'id': 56506250,
#      'node_id': 'MDQ6VXNlcjU2NTA2MjUw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/56506250?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Atrael',
#      'html_url': 'https://github.com/Atrael',
#      'followers_url': 'https://api.github.com/users/Atrael/followers',
#      'following_url': 'https://api.github.com/users/Atrael/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Atrael/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Atrael/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Atrael/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Atrael/orgs',
#      'repos_url': 'https://api.github.com/users/Atrael/repos',
#      'events_url': 'https://api.github.com/users/Atrael/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Atrael/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-01T12:45:13Z',
#     'updated_at': '2019-12-01T12:45:13Z',
#     'closed_at': None,
#     'author_association': 'COLLABORATOR',
#     'body': 'Student chciałby mieć możliwość podglądu uzyskanych obecności z danego przedmiotu.\r\n\r\nDodać moduł funkcjonalny aplikacji przechowujący dane o zdobytych obecnościach z danego przedmiotu. Moduł będzie posiadać zakładkę "Obecność" i listę przedmiotów przypisanych do konta studenta. Przejście do konkretnego przedmiotu ukazuje tabelę ze zdobytymi obecnościami z danego przedmiotu wraz z datą.'}},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102555',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 58120132,
#    'login': 'jeanmichael1993',
#    'display_login': 'jeanmichael1993',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jeanmichael1993',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58120132?'},
#   'repo': {'id': 223652841,
#    'name': 'jeanmichael1993/jeanmichael',
#    'url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael'},
#   'payload': {'action': 'opened',
#    'number': 6,
#    'pull_request': {'url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/pulls/6',
#     'id': 347325652,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0MzQ3MzI1NjUy',
#     'html_url': 'https://github.com/jeanmichael1993/jeanmichael/pull/6',
#     'diff_url': 'https://github.com/jeanmichael1993/jeanmichael/pull/6.diff',
#     'patch_url': 'https://github.com/jeanmichael1993/jeanmichael/pull/6.patch',
#     'issue_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/issues/6',
#     'number': 6,
#     'state': 'open',
#     'locked': False,
#     'title': 'Matriz Ex01',
#     'user': {'login': 'jeanmichael1993',
#      'id': 58120132,
#      'node_id': 'MDQ6VXNlcjU4MTIwMTMy',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/58120132?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/jeanmichael1993',
#      'html_url': 'https://github.com/jeanmichael1993',
#      'followers_url': 'https://api.github.com/users/jeanmichael1993/followers',
#      'following_url': 'https://api.github.com/users/jeanmichael1993/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/jeanmichael1993/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/jeanmichael1993/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/jeanmichael1993/subscriptions',
#      'organizations_url': 'https://api.github.com/users/jeanmichael1993/orgs',
#      'repos_url': 'https://api.github.com/users/jeanmichael1993/repos',
#      'events_url': 'https://api.github.com/users/jeanmichael1993/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/jeanmichael1993/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '',
#     'created_at': '2019-12-01T12:45:13Z',
#     'updated_at': '2019-12-01T12:45:13Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'commits_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/pulls/6/commits',
#     'review_comments_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/pulls/6/comments',
#     'review_comment_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/issues/6/comments',
#     'statuses_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/statuses/8ba541df37831e969650eb0a57a4eaaf0bd9392f',
#     'head': {'label': 'jeanmichael1993:Master',
#      'ref': 'Master',
#      'sha': '8ba541df37831e969650eb0a57a4eaaf0bd9392f',
#      'user': {'login': 'jeanmichael1993',
#       'id': 58120132,
#       'node_id': 'MDQ6VXNlcjU4MTIwMTMy',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/58120132?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jeanmichael1993',
#       'html_url': 'https://github.com/jeanmichael1993',
#       'followers_url': 'https://api.github.com/users/jeanmichael1993/followers',
#       'following_url': 'https://api.github.com/users/jeanmichael1993/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jeanmichael1993/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jeanmichael1993/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jeanmichael1993/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jeanmichael1993/orgs',
#       'repos_url': 'https://api.github.com/users/jeanmichael1993/repos',
#       'events_url': 'https://api.github.com/users/jeanmichael1993/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jeanmichael1993/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 223652841,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjM2NTI4NDE=',
#       'name': 'jeanmichael',
#       'full_name': 'jeanmichael1993/jeanmichael',
#       'private': False,
#       'owner': {'login': 'jeanmichael1993',
#        'id': 58120132,
#        'node_id': 'MDQ6VXNlcjU4MTIwMTMy',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/58120132?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jeanmichael1993',
#        'html_url': 'https://github.com/jeanmichael1993',
#        'followers_url': 'https://api.github.com/users/jeanmichael1993/followers',
#        'following_url': 'https://api.github.com/users/jeanmichael1993/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jeanmichael1993/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jeanmichael1993/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jeanmichael1993/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jeanmichael1993/orgs',
#        'repos_url': 'https://api.github.com/users/jeanmichael1993/repos',
#        'events_url': 'https://api.github.com/users/jeanmichael1993/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jeanmichael1993/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jeanmichael1993/jeanmichael',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael',
#       'forks_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/forks',
#       'keys_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/teams',
#       'hooks_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/events',
#       'assignees_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/tags',
#       'blobs_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/languages',
#       'stargazers_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/subscription',
#       'commits_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/merges',
#       'archive_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/downloads',
#       'issues_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/deployments',
#       'created_at': '2019-11-23T21:03:50Z',
#       'updated_at': '2019-12-01T02:17:05Z',
#       'pushed_at': '2019-12-01T12:45:02Z',
#       'git_url': 'git://github.com/jeanmichael1993/jeanmichael.git',
#       'ssh_url': 'git@github.com:jeanmichael1993/jeanmichael.git',
#       'clone_url': 'https://github.com/jeanmichael1993/jeanmichael.git',
#       'svn_url': 'https://github.com/jeanmichael1993/jeanmichael',
#       'homepage': None,
#       'size': 7,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'jeanmichael1993:master',
#      'ref': 'master',
#      'sha': 'e83bbe0d4dd6c2aecefd46f71cb7e42d0cf259a1',
#      'user': {'login': 'jeanmichael1993',
#       'id': 58120132,
#       'node_id': 'MDQ6VXNlcjU4MTIwMTMy',
#       'avatar_url': 'https://avatars3.githubusercontent.com/u/58120132?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/jeanmichael1993',
#       'html_url': 'https://github.com/jeanmichael1993',
#       'followers_url': 'https://api.github.com/users/jeanmichael1993/followers',
#       'following_url': 'https://api.github.com/users/jeanmichael1993/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/jeanmichael1993/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/jeanmichael1993/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/jeanmichael1993/subscriptions',
#       'organizations_url': 'https://api.github.com/users/jeanmichael1993/orgs',
#       'repos_url': 'https://api.github.com/users/jeanmichael1993/repos',
#       'events_url': 'https://api.github.com/users/jeanmichael1993/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/jeanmichael1993/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 223652841,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMjM2NTI4NDE=',
#       'name': 'jeanmichael',
#       'full_name': 'jeanmichael1993/jeanmichael',
#       'private': False,
#       'owner': {'login': 'jeanmichael1993',
#        'id': 58120132,
#        'node_id': 'MDQ6VXNlcjU4MTIwMTMy',
#        'avatar_url': 'https://avatars3.githubusercontent.com/u/58120132?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/jeanmichael1993',
#        'html_url': 'https://github.com/jeanmichael1993',
#        'followers_url': 'https://api.github.com/users/jeanmichael1993/followers',
#        'following_url': 'https://api.github.com/users/jeanmichael1993/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/jeanmichael1993/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/jeanmichael1993/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/jeanmichael1993/subscriptions',
#        'organizations_url': 'https://api.github.com/users/jeanmichael1993/orgs',
#        'repos_url': 'https://api.github.com/users/jeanmichael1993/repos',
#        'events_url': 'https://api.github.com/users/jeanmichael1993/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/jeanmichael1993/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/jeanmichael1993/jeanmichael',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael',
#       'forks_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/forks',
#       'keys_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/teams',
#       'hooks_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/hooks',
#       'issue_events_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/events',
#       'assignees_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/tags',
#       'blobs_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/languages',
#       'stargazers_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/stargazers',
#       'contributors_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/contributors',
#       'subscribers_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/subscribers',
#       'subscription_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/subscription',
#       'commits_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/merges',
#       'archive_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/downloads',
#       'issues_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/deployments',
#       'created_at': '2019-11-23T21:03:50Z',
#       'updated_at': '2019-12-01T02:17:05Z',
#       'pushed_at': '2019-12-01T12:45:02Z',
#       'git_url': 'git://github.com/jeanmichael1993/jeanmichael.git',
#       'ssh_url': 'git@github.com:jeanmichael1993/jeanmichael.git',
#       'clone_url': 'https://github.com/jeanmichael1993/jeanmichael.git',
#       'svn_url': 'https://github.com/jeanmichael1993/jeanmichael',
#       'homepage': None,
#       'size': 7,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Java',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 0,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/pulls/6'},
#      'html': {'href': 'https://github.com/jeanmichael1993/jeanmichael/pull/6'},
#      'issue': {'href': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/issues/6'},
#      'comments': {'href': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/issues/6/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/pulls/6/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/pulls/6/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/jeanmichael1993/jeanmichael/statuses/8ba541df37831e969650eb0a57a4eaaf0bd9392f'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 43,
#     'deletions': 0,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102554',
#   'type': 'DeleteEvent',
#   'actor': {'id': 52099893,
#    'login': 'shelchkov',
#    'display_login': 'shelchkov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/shelchkov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52099893?'},
#   'repo': {'id': 211517098,
#    'name': 'shelchkov/providers',
#    'url': 'https://api.github.com/repos/shelchkov/providers'},
#   'payload': {'ref': 'buttonState',
#    'ref_type': 'branch',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102549',
#   'type': 'IssuesEvent',
#   'actor': {'id': 2179996,
#    'login': 'saurabhheda',
#    'display_login': 'saurabhheda',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saurabhheda',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2179996?'},
#   'repo': {'id': 43191201,
#    'name': 'bloomberg/bqplot',
#    'url': 'https://api.github.com/repos/bloomberg/bqplot'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/bloomberg/bqplot/issues/978',
#     'repository_url': 'https://api.github.com/repos/bloomberg/bqplot',
#     'labels_url': 'https://api.github.com/repos/bloomberg/bqplot/issues/978/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/bloomberg/bqplot/issues/978/comments',
#     'events_url': 'https://api.github.com/repos/bloomberg/bqplot/issues/978/events',
#     'html_url': 'https://github.com/bloomberg/bqplot/issues/978',
#     'id': 530725893,
#     'node_id': 'MDU6SXNzdWU1MzA3MjU4OTM=',
#     'number': 978,
#     'title': 'bqplot Tooltip lables which are different from plot labels',
#     'user': {'login': 'saurabhheda',
#      'id': 2179996,
#      'node_id': 'MDQ6VXNlcjIxNzk5OTY=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/2179996?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/saurabhheda',
#      'html_url': 'https://github.com/saurabhheda',
#      'followers_url': 'https://api.github.com/users/saurabhheda/followers',
#      'following_url': 'https://api.github.com/users/saurabhheda/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/saurabhheda/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/saurabhheda/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/saurabhheda/subscriptions',
#      'organizations_url': 'https://api.github.com/users/saurabhheda/orgs',
#      'repos_url': 'https://api.github.com/users/saurabhheda/repos',
#      'events_url': 'https://api.github.com/users/saurabhheda/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/saurabhheda/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2019-12-01T12:45:13Z',
#     'updated_at': '2019-12-01T12:45:13Z',
#     'closed_at': None,
#     'author_association': 'NONE',
#     'body': "Hi, \r\nCan we have different tooltip labels which are different from labels. I have an implementation where I tried to change the same but not reflected in the figure. Something like below. \r\n\r\n`tooltip_widget = Tooltip(fields=['size', 'field'], formats=['0f', ''])` where I defined field in the pie function as \r\n\r\n`  pie = Pie(sizes=prod_df[name].value_counts(),inner_radius=0.05,radius=radius, scales={'color': sc},\r\n               display_labels='outside',labels=label_list,fields=list(prod_df[name].value_counts().index),\r\n             tooltip=tooltip_widget, interactions = {'hover': 'tooltip'}, selected_style={'fill': 'red'})`\r\n\r\nPlot shown is something like below where I don't see field values in the plot. Any pointers to achieve output.\r\n\r\n![image](https://user-images.githubusercontent.com/2179996/69914122-66139300-1466-11ea-89eb-be55d1cef5c7.png)\r\n"}},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z',
#   'org': {'id': 1416818,
#    'login': 'bloomberg',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/bloomberg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1416818?'}},
#  {'id': '10983102548',
#   'type': 'CreateEvent',
#   'actor': {'id': 29943745,
#    'login': 'MaestroJolly',
#    'display_login': 'MaestroJolly',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MaestroJolly',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/29943745?'},
#   'repo': {'id': 225159887,
#    'name': 'MaestroJolly/node-jwt-authentication',
#    'url': 'https://api.github.com/repos/MaestroJolly/node-jwt-authentication'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Email and Password NodeJS Authentication Built With Mongoose, JWT And Express',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T12:45:14Z'},
#  {'id': '10983102547',
#   'type': 'WatchEvent',
#   'actor': {'id': 55954259,
#    'login': 'yocorn',
#    'display_login': 'yocorn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/yocorn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/55954259?'},
#   'repo': {'id': 107153495,
#    'name': 'CVEProject/cvelist',
#    'url': 'https://api.github.com/repos/CVEProject/cvelist'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2019-12-01T12:45:13Z',
#   'org': {'id': 18195825,
#    'login': 'CVEProject',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/CVEProject',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18195825?'}},
#  {'id': '10983102546',
#   'type': 'CreateEvent',
#   'actor': {'id': 486085,
#    'login': 'alvises',
#    'display_login': 'alvises',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alvises',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/486085?'},
#   'repo': {'id': 225159888,
#    'name': 'alvises/aoc2019',
#    'url': 'https://api.github.com/repos/alvises/aoc2019'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': 'Advent Of Code 2019 in Elixir',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2019-12-01T12:45:13Z'},
#  {'id': '10983102545',
#   'type': 'ForkEvent',
#   'actor': {'id': 46855370,
#    'login': 'gggumiiinqiii',
#    'display_login': 'gggumiiinqiii',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/gggumiiinqiii',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46855370?'},
#   'repo': {'id': 152616683,
#    'name': 'shhw/gitdir',
#    'url': 'https://api.github.com/repos/shhw/gitdir'},
#   'payload': {'forkee': {'id': 225159886,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyMjUxNTk4ODY=',
#     'name': 'gitdir',
#     'full_name': 'gggumiiinqiii/gitdir',
#     'private': False,
#     'owner': {'login': 'gggumiiinqiii',
#      'id': 46855370,
#      'node_id': 'MDQ6VXNlcjQ2ODU1Mzcw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/46855370?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gggumiiinqiii',
# ...
#       'following_url': 'https://api.github.com/users/yoshimitsuEgashira/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/yoshimitsuEgashira/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/yoshimitsuEgashira/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/yoshimitsuEgashira/subscriptions',
#       'organizations_url': 'https://api.github.com/users/yoshimitsuEgashira/orgs',
#       'repos_url': 'https://api.github.com/users/yoshimitsuEgashira/repos',
#       'events_url': 'https://api.github.com/users/yoshimitsuEgashira/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/yoshimitsuEgashira/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 216552207,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTY1NTIyMDc=',
#       'name': 'echo-tutorial',
#       'full_name': 'yoshimitsuEgashira/echo-tutorial',
#       'private': False,
#       'owner': {'login': 'yoshimitsuEgashira',
#        'id': 38056766,
#        'node_id': 'MDQ6VXNlcjM4MDU2NzY2',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/38056766?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/yoshimitsuEgashira',
#        'html_url': 'https://github.com/yoshimitsuEgashira',
#        'followers_url': 'https://api.github.com/users/yoshimitsuEgashira/followers',
#        'following_url': 'https://api.github.com/users/yoshimitsuEgashira/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/yoshimitsuEgashira/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/yoshimitsuEgashira/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/yoshimitsuEgashira/subscriptions',
#        'organizations_url': 'https://api.github.com/users/yoshimitsuEgashira/orgs',
#        'repos_url': 'https://api.github.com/users/yoshimitsuEgashira/repos',
#        'events_url': 'https://api.github.com/users/yoshimitsuEgashira/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/yoshimitsuEgashira/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/yoshimitsuEgashira/echo-tutorial',
#       'description': 'High performance, minimalist Go web framework :rocket: ',
#       'fork': False,
#       'url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial',
#       'forks_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/forks',
#       'keys_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/teams',
#       'hooks_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/hooks',
#       'issue_events_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/events',
#       'assignees_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/tags',
#       'blobs_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/languages',
#       'stargazers_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/stargazers',
#       'contributors_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/contributors',
#       'subscribers_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/subscribers',
#       'subscription_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/subscription',
#       'commits_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/merges',
#       'archive_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/downloads',
#       'issues_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/deployments',
#       'created_at': '2019-10-21T11:33:16Z',
#       'updated_at': '2019-11-09T01:42:10Z',
#       'pushed_at': '2019-12-01T12:41:52Z',
#       'git_url': 'git://github.com/yoshimitsuEgashira/echo-tutorial.git',
#       'ssh_url': 'git@github.com:yoshimitsuEgashira/echo-tutorial.git',
#       'clone_url': 'https://github.com/yoshimitsuEgashira/echo-tutorial.git',
#       'svn_url': 'https://github.com/yoshimitsuEgashira/echo-tutorial',
#       'homepage': 'https://echo.labstack.com',
#       'size': 10,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': None,
#       'forks': 0,
#       'open_issues': 7,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'yoshimitsuEgashira:master',
#      'ref': 'master',
#      'sha': 'b67dd6892e214c069613bf6f12ae66ebce0a1438',
#      'user': {'login': 'yoshimitsuEgashira',
#       'id': 38056766,
#       'node_id': 'MDQ6VXNlcjM4MDU2NzY2',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/38056766?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/yoshimitsuEgashira',
#       'html_url': 'https://github.com/yoshimitsuEgashira',
#       'followers_url': 'https://api.github.com/users/yoshimitsuEgashira/followers',
#       'following_url': 'https://api.github.com/users/yoshimitsuEgashira/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/yoshimitsuEgashira/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/yoshimitsuEgashira/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/yoshimitsuEgashira/subscriptions',
#       'organizations_url': 'https://api.github.com/users/yoshimitsuEgashira/orgs',
#       'repos_url': 'https://api.github.com/users/yoshimitsuEgashira/repos',
#       'events_url': 'https://api.github.com/users/yoshimitsuEgashira/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/yoshimitsuEgashira/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 216552207,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyMTY1NTIyMDc=',
#       'name': 'echo-tutorial',
#       'full_name': 'yoshimitsuEgashira/echo-tutorial',
#       'private': False,
#       'owner': {'login': 'yoshimitsuEgashira',
#        'id': 38056766,
#        'node_id': 'MDQ6VXNlcjM4MDU2NzY2',
#        'avatar_url': 'https://avatars2.githubusercontent.com/u/38056766?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/yoshimitsuEgashira',
#        'html_url': 'https://github.com/yoshimitsuEgashira',
#        'followers_url': 'https://api.github.com/users/yoshimitsuEgashira/followers',
#        'following_url': 'https://api.github.com/users/yoshimitsuEgashira/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/yoshimitsuEgashira/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/yoshimitsuEgashira/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/yoshimitsuEgashira/subscriptions',
#        'organizations_url': 'https://api.github.com/users/yoshimitsuEgashira/orgs',
#        'repos_url': 'https://api.github.com/users/yoshimitsuEgashira/repos',
#        'events_url': 'https://api.github.com/users/yoshimitsuEgashira/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/yoshimitsuEgashira/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/yoshimitsuEgashira/echo-tutorial',
#       'description': 'High performance, minimalist Go web framework :rocket: ',
#       'fork': False,
#       'url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial',
#       'forks_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/forks',
#       'keys_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/teams',
#       'hooks_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/hooks',
#       'issue_events_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/events',
#       'assignees_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/tags',
#       'blobs_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/languages',
#       'stargazers_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/stargazers',
#       'contributors_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/contributors',
#       'subscribers_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/subscribers',
#       'subscription_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/subscription',
#       'commits_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/merges',
#       'archive_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/downloads',
#       'issues_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/deployments',
#       'created_at': '2019-10-21T11:33:16Z',
#       'updated_at': '2019-11-09T01:42:10Z',
#       'pushed_at': '2019-12-01T12:41:52Z',
#       'git_url': 'git://github.com/yoshimitsuEgashira/echo-tutorial.git',
#       'ssh_url': 'git@github.com:yoshimitsuEgashira/echo-tutorial.git',
#       'clone_url': 'https://github.com/yoshimitsuEgashira/echo-tutorial.git',
#       'svn_url': 'https://github.com/yoshimitsuEgashira/echo-tutorial',
#       'homepage': 'https://echo.labstack.com',
#       'size': 10,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 7,
#       'license': None,
#       'forks': 0,
#       'open_issues': 7,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/pulls/14'},
#      'html': {'href': 'https://github.com/yoshimitsuEgashira/echo-tutorial/pull/14'},
#      'issue': {'href': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/issues/14'},
#      'comments': {'href': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/issues/14/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/pulls/14/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/pulls/14/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/yoshimitsuEgashira/echo-tutorial/statuses/dcfb9f1e1de96597c55d0cb9bf24f7784dabf567'}},
#     'author_association': 'OWNER',
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 5,
#     'additions': 226,
#     'deletions': 5,
#     'changed_files': 8}},
#   'public': True,
#   'created_at': '2019-12-01T12:45:13Z'}]

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
json.loads(r.text)
# Out:
# {'@odata.context': 'http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel',
#  '@odata.count': 100,
#  'value': [{'WaterLevel': 164.36,
#    'StationIdentifier': '2420H036',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 202.65,
#    'StationIdentifier': '2560H024',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 138.66,
#    'StationIdentifier': '1730H066',
#    'RecordTime': 'Dec 1, 2019 8:50:00 PM'},
#   {'WaterLevel': 109.96,
#    'StationIdentifier': '2420H019',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 226.21,
#    'StationIdentifier': '1730H070',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 366.37,
#    'StationIdentifier': '2560H017',
#    'RecordTime': 'Dec 1, 2019 8:20:00 PM'},
#   {'WaterLevel': 5.69,
#    'StationIdentifier': '1650H013',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 740.44,
#    'StationIdentifier': '1730H077',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 261.63,
#    'StationIdentifier': '2370H025',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 25.74,
#    'StationIdentifier': '1580H017',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 32.15,
#    'StationIdentifier': '2500H003',
#    'RecordTime': 'Dec 1, 2019 8:20:00 PM'},
#   {'WaterLevel': 245.48,
#    'StationIdentifier': '1730H074',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 20.21,
#    'StationIdentifier': '1540H032',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 1.55,
#    'StationIdentifier': '1630H030',
#    'RecordTime': 'Nov 30, 2019 10:50:00 AM'},
#   {'WaterLevel': 38.99,
#    'StationIdentifier': '1540H039',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 65.81,
#    'StationIdentifier': '1630H036',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 248.86,
#    'StationIdentifier': '1730H072',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 12.76,
#    'StationIdentifier': '1540H029',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 0.19,
#    'StationIdentifier': '1580H022',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 79.31,
#    'StationIdentifier': '2420H043',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 32.01,
#    'StationIdentifier': '1540H037',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 0.32,
#    'StationIdentifier': '1630H032',
#    'RecordTime': 'Nov 30, 2019 10:50:00 AM'},
#   {'WaterLevel': 10.14,
#    'StationIdentifier': '1730H068',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 145,
#    'StationIdentifier': '1510H084',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 380.47,
#    'StationIdentifier': '1430H037',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 2.99,
#    'StationIdentifier': '1670H004',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 192.56,
#    'StationIdentifier': '2370H004',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 23.28,
#    'StationIdentifier': '1540H033',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 26.17,
#    'StationIdentifier': '1630H027',
#    'RecordTime': 'Nov 30, 2019 10:50:00 AM'},
#   {'WaterLevel': 0.3,
#    'StationIdentifier': '1550H012',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': -0.34,
#    'StationIdentifier': '1350H031',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 87.53,
#    'StationIdentifier': '1430H030',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 0.48,
#    'StationIdentifier': '1660H012',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 207.18,
#    'StationIdentifier': '2200H025',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 1068.95,
#    'StationIdentifier': '1510H080',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 48.38,
#    'StationIdentifier': '1430H054',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 27.16,
#    'StationIdentifier': '1540H030',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 175.92,
#    'StationIdentifier': '1350H029',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 23.57,
#    'StationIdentifier': '1430H028',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 0.27,
#    'StationIdentifier': '1650H015',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 39.77,
#    'StationIdentifier': '1630H005',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 187.71,
#    'StationIdentifier': '1510H079',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 95.66,
#    'StationIdentifier': '1430H051',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 0.02,
#    'StationIdentifier': '1540H009',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 145.82,
#    'StationIdentifier': '1350H027',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 639.38,
#    'StationIdentifier': '1420H057',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 278.36,
#    'StationIdentifier': '1630H034',
#    'RecordTime': 'Nov 30, 2019 11:20:00 AM'},
#   {'WaterLevel': 20.74,
#    'StationIdentifier': '1590H013',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 20.6,
#    'StationIdentifier': '1510H071',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 72.37,
#    'StationIdentifier': '1430H047',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 78.23,
#    'StationIdentifier': '1520H008',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 220.77,
#    'StationIdentifier': '1350H020',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 55.22,
#    'StationIdentifier': '1400H018',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 752.39,
#    'StationIdentifier': '1510H082',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 704.2,
#    'StationIdentifier': '1420H054',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 82.99,
#    'StationIdentifier': '1430H058',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 440.49,
#    'StationIdentifier': '1420H058',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 317.98,
#    'StationIdentifier': '1510H086',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 0.29,
#    'StationIdentifier': '1340H014',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 191.55,
#    'StationIdentifier': '1400H009',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 12.2,
#    'StationIdentifier': '1510H058',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 54.05,
#    'StationIdentifier': '1420H049',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 98.35,
#    'StationIdentifier': '1350H016',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 155.51,
#    'StationIdentifier': '1510H050',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 346.54,
#    'StationIdentifier': '1510H075',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 7.35,
#    'StationIdentifier': '1340H011',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 12.15,
#    'StationIdentifier': '1140H108',
#    'RecordTime': 'Dec 1, 2019 8:45:00 PM'},
#   {'WaterLevel': 318.94,
#    'StationIdentifier': '1420H055',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 624.93,
#    'StationIdentifier': '1400H015',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 50.04,
#    'StationIdentifier': '1340H015',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 24.97,
#    'StationIdentifier': '1430H061',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 253.91,
#    'StationIdentifier': '1350H022',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 2.59,
#    'StationIdentifier': '1320H001',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 6.94,
#    'StationIdentifier': '1140H082',
#    'RecordTime': 'Dec 1, 2019 8:30:00 PM'},
#   {'WaterLevel': 49.12,
#    'StationIdentifier': '1140H106',
#    'RecordTime': 'Dec 1, 2019 8:45:00 PM'},
#   {'WaterLevel': 0.55,
#    'StationIdentifier': '1350H025',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 79.82,
#    'StationIdentifier': '1430H056',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 145.15,
#    'StationIdentifier': '2200H029',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 282.04,
#    'StationIdentifier': '1350H018',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 52.22,
#    'StationIdentifier': '1300H023',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 22.08,
#    'StationIdentifier': '1140H049',
#    'RecordTime': 'Dec 1, 2019 8:30:00 PM'},
#   {'WaterLevel': 263.67,
#    'StationIdentifier': '1140H099',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 256.27,
#    'StationIdentifier': '1350H023',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 91.71,
#    'StationIdentifier': '1430H045',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 72.09,
#    'StationIdentifier': '1850H004',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 19.45,
#    'StationIdentifier': '1430H040',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 251.43,
#    'StationIdentifier': '1300H020',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 12.96,
#    'StationIdentifier': '2560H023',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 0.54,
#    'StationIdentifier': '2560H020',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 156.02,
#    'StationIdentifier': '2370H019',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 169.79,
#    'StationIdentifier': '1350H001',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 47.05,
#    'StationIdentifier': '1740H010',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': -1.36,
#    'StationIdentifier': '1300H022',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 100.45,
#    'StationIdentifier': '1300H016',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 58.46,
#    'StationIdentifier': '2370H017',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 0.71,
#    'StationIdentifier': '1650H012',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 106.72,
#    'StationIdentifier': '2200H026',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 246.84,
#    'StationIdentifier': '1340H012',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 1.11,
#    'StationIdentifier': '1740H008',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'},
#   {'WaterLevel': 40.94,
#    'StationIdentifier': '1290H002',
#    'RecordTime': 'Dec 1, 2019 8:40:00 PM'}],
#  '@odata.nextLink': 'http://odata.wra.gov.tw/v4/RealtimeWaterLevel?$skip=100&$top=100'}
